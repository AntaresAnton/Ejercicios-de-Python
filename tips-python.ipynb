# %% [markdown]
# print()                 : Imprime un mensaje en la consola.
# input()                 : Recibe la entrada del usuario desde la consola.
# len()                   : Devuelve la longitud de un objeto (como una lista, tupla, cadena, etc.).
# range()                 : Genera una secuencia de números.
# type()                  : Devuelve el tipo de un objeto.
# int()                   : Convierte un valor en un entero.
# float()                 : Convierte un valor en un número de punto flotante.
# str()                   : Convierte un valor en una cadena de texto.
# list()                  : Crea una lista.
# tuple()                 : Crea una tupla.
# dict()                  : Crea un diccionario.
# set()                   : Crea un conjunto.
# bool()                  : Crea un valor booleano (True o False).
# abs()                   : Devuelve el valor absoluto de un número.
# max()                   : Devuelve el valor máximo de una secuencia.
# min()                   : Devuelve el valor mínimo de una secuencia.
# sum()                   : Calcula la suma de una secuencia.
# sorted()                : Ordena una secuencia.
# reversed()              : Invierte una secuencia.
# zip()                   : Combina dos secuencias en una lista de tuplas.
# map()                   : Aplica una función a cada elemento de una secuencia.
# filter()                : Filtra elementos de una secuencia según una función.
# reduce()                : Aplica una función acumulativa a los elementos de una secuencia.
# format()                : Formatea una cadena de texto.
# split()                 : Divide una cadena en subcadenas.
# join()                  : Une elementos de una lista en una cadena.
# strip()                 : Elimina espacios en blanco al inicio y final de una cadena.
# replace()               : Reemplaza parte de una cadena con otra.
# append()                : Agrega un elemento al final de una lista.
# extend()                : Extiende una lista con los elementos de otra lista.
# insert()                : Inserta un elemento en una posición específica de la lista.
# remove()                : Elimina el primer elemento con el valor especificado de la lista.
# pop()                   : Elimina y devuelve el elemento de una posición específica en la lista.
# clear()                 : Elimina todos los elementos de una lista.
# count()                 : Cuenta cuántas veces aparece un elemento en una lista.
# index()                 : Devuelve el índice de la primera aparición de un elemento en la lista.
# in                      : Verifica si un elemento está presente en una secuencia.
# not in                  : Verifica si un elemento no está presente en una secuencia.
# del                     : Elimina un objeto o un elemento de una lista, diccionario, etc.
# is                      : Comprueba si dos variables se refieren al mismo objeto.
# pass                    : Sentencia nula; no hace nada.
# break                   : Sale de un bucle (for o while) prematuramente.
# continue                : Salta a la siguiente iteración de un bucle (for o while).
# return                  : Devuelve un valor desde una función.
# yield                   : Devuelve un valor desde un generador y pausa la ejecución.
# lambda                  : Crea funciones anónimas o lambda functions.
# def                     : Define una función personalizada.
# class                   : Define una clase.
# global                  : Permite modificar variables globales dentro de una función.
# nonlocal                : Permite modificar variables en un ámbito externo a la función actual.
# init()                  : Método especial para inicializar objetos en una clase.
# str()                   : Método especial para representar objetos como cadenas de texto.
# repr()                  : Método especial para representar objetos de manera detallada y precisa.
# len()                   : Método especial para obtener la longitud de un objeto.
# getitem()               : Método especial para acceder a elementos de un objeto mediante índices.
# setitem()               : Método especial para asignar valores a elementos de un objeto mediante índices.
# delitem()               : Método especial para eliminar elementos de un objeto mediante índices.
# contains()              : Método especial para verificar si un objeto contiene cierto valor.
# iter()                  : Método especial para iterar sobre los elementos de un objeto.
# next()                  : Devuelve el siguiente elemento en la iteración de un objeto iterable.
# open()                  : Abre un archivo en modo lectura, escritura, etc.
# close()                 : Cierra un archivo abierto previamente.
# read()                  : Lee el contenido de un archivo abierto.
# write()                 : Escribe en un archivo abierto.
# seek()                  : Mueve el puntero de lectura/escritura a una posición específica en el archivo.
# tell()                  : Devuelve la posición actual del puntero en el archivo.
# with                    : Gestiona el contexto de un objeto, como un archivo, asegurando su cierre adecuado al salir del bloque with.
# try                     : Inicia un bloque para manejar excepciones potenciales.
# except                  : Captura y maneja excepciones específicas dentro de un bloque try.
# raise                   : Provoca manualmente una excepción especificada.
# finally                 : Define un bloque que se ejecuta siempre, independientemente de si se produce una excepción o no.
# assert                  : Verifica si una condición es verdadera; si no lo es, genera una excepción AssertionError.
# import                  : Importa módulos o paquetes en Python para utilizar sus funciones y variables.
# from                    : Importa partes específicas de un módulo o paquete en Python.
# as                      : Permite asignar un alias a módulos o paquetes importados para facilitar su uso en el código.
# *                       : Operador utilizado para importar todos los elementos de un módulo en Python.
# math.sqrt()             : Devuelve la raíz cuadrada de un número utilizando el módulo math.
# math.floor()            : Redondea hacia abajo un número decimal utilizando el módulo math.
# math.ceil()             : Redondea hacia arriba un número decimal utilizando el módulo math.
# random.random()         : Genera un número aleatorio entre 0 y 1 utilizando el módulo random.
# random.randint()        : Genera un número entero aleatorio dentro de un rango especificado utilizando el módulo random.
# random.choice()         : Elige aleatoriamente un elemento de una secuencia utilizando el módulo random.
# datetime.datetime.now() : Devuelve la fecha y hora actual utilizando el módulo datetime.
# datetime.timedelta()    : Representa una duración o diferencia entre dos fechas y horas utilizando el módulo datetime.
# os.getcwd()             : Devuelve el directorio actual de trabajo utilizando el módulo os.
# os.remove()             : Elimina un archivo utilizando el módulo os.
# os.rename()             : Renombra un archivo o directorio utilizando el módulo os.
# os.path.isfile()        : Verifica si una ruta es un archivo utilizando el módulo os.
# os.path.isdir()         : Verifica si una ruta es un directorio utilizando el módulo os.
# sys.argv                : Lista que contiene los argumentos pasados al script de Python desde la línea de comandos.
# sys.exit()              : Sale del programa de Python de forma inmediata.
# sys.stdin               : Objeto que representa la entrada estándar (normalmente el teclado).
# sys.stdout              : Objeto que representa la salida estándar (normalmente la consola).
# sys.stderr              : Objeto que representa la salida de errores estándar (normalmente la consola).
# platform.system()       : Devuelve el nombre del sistema operativo subyacente utilizando el módulo platform.
# platform.platform()     : Devuelve una cadena que describe la plataforma en la que se está ejecutando Python utilizando el módulo platform.
